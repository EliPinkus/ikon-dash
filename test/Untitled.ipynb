# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://www.onthesnow.com/ikon-pass/skireport'
page=requests.get(url)
soup = BeautifulSoup(page.text, 'lxml')
tbodies = soup.find_all('tbody')
tbody = tbodies[0]
spots = []
for row in tbody.findChildren(recursive=False)[:-1]:
    res = {}
    row_items = row.findChildren(recursive=False)
    if len(row_items) < 5:
        continue
    for i in range(len(row_items)):
        if i == 0:
            res['name'] = row_items[0].find('span').getText()
            res['last_update'] = row_items[0].find('time').getText()
            res['report_link'] = 'https://www.onthesnow.com' + row_items[0].find('a', href=True)['href']
        if i==1:
            res['snowfall_amount'] = row_items[1].find('span', {'class': 'h4 styles_h4__318ae'}).getText()
            res['last_snowfall'] = row_items[1].find('time').getText()
        if i==2:
            res['base_depth'] = row_items[2].find('span', {'class', 'h4 styles_h4__318ae'}).getText()
            res['main_surface'] = row_items[2].find('div').getText()
        if i==3:
            open_trails = row_items[3].find('span', {'class', 'h4 styles_h4__318ae'}).getText()
            res['open_trails'], res['total_trails'] = open_trails.split('/')
        if i==4:
            open_lifts = row_items[4].find('span', {'class', 'h4 styles_h4__318ae'} ).getText()
            res['open_lifts'], res['total_lifts'] = open_lifts.split('/')
    spots.append(res)
spots
pd.DataFrame(spots)
# Out:
#                        name   last_update  \
# 0             Alta Ski Area  12 hours ago
# 1   Arapahoe Basin Ski Area  20 hours ago
# 2            Aspen Snowmass  23 hours ago
# 3             Bear Mountain  19 hours ago
# 4                   Big Sky  22 hours ago
# 5             Blue Mountain  20 hours ago
# 6     Boyne Mountain Resort  20 hours ago
# 7           Brighton Resort  20 hours ago
# 8           Copper Mountain  23 hours ago
# 9          Crystal Mountain  18 hours ago
# 10         Cypress Mountain  19 hours ago
# 11       Deer Valley Resort  22 hours ago
# 12   Eldora Mountain Resort  22 hours ago
# 13             Jackson Hole  21 hours ago
# 14            June Mountain    2 days ago
# 15              Lake Louise  22 hours ago
# 16            Loon Mountain  22 hours ago
# 17         Mammoth Mountain  19 hours ago
# 18             Mt. Bachelor  18 hours ago
# 19              Mt. Norquay  20 hours ago
# 20          Palisades Tahoe  20 hours ago
# 21               Revelstoke  19 hours ago
# 22              Snow Summit  19 hours ago
# 23                 Snowbird  22 hours ago
#
#                                           report_link snowfall_amount  \
# 0   https://www.onthesnow.com/utah/alta-ski-area/s...              6"
# 1   https://www.onthesnow.com/colorado/arapahoe-ba...              2"
# 2   https://www.onthesnow.com/colorado/aspen-snowm...              2"
# 3   https://www.onthesnow.com/california/bear-moun...              4"
# 4   https://www.onthesnow.com/montana/big-sky-reso...              6"
# 5   https://www.onthesnow.com/ontario/blue-mountai...              5"
# 6   https://www.onthesnow.com/michigan/boyne-mount...              2"
# 7   https://www.onthesnow.com/utah/brighton-resort...              1"
# 8   https://www.onthesnow.com/colorado/copper-moun...              1"
# 9   https://www.onthesnow.com/washington/crystal-m...              3"
# 10  https://www.onthesnow.com/british-columbia/cyp...              1"
# 11  https://www.onthesnow.com/utah/deer-valley-res...              1"
# 12  https://www.onthesnow.com/colorado/eldora-moun...              7"
# 13  https://www.onthesnow.com/wyoming/jackson-hole...              2"
# 14  https://www.onthesnow.com/california/june-moun...             81"
# 15  https://www.onthesnow.com/alberta/lake-louise/...              1"
# 16  https://www.onthesnow.com/new-hampshire/loon-m...              3"
# 17  https://www.onthesnow.com/california/mammoth-m...              3"
# 18  https://www.onthesnow.com/oregon/mt-bachelor/s...              1"
# 19  https://www.onthesnow.com/alberta/ski-banff-no...              1"
# 20  https://www.onthesnow.com/california/squaw-val...              2"
# 21  https://www.onthesnow.com/british-columbia/rev...              2"
# 22  https://www.onthesnow.com/california/snow-summ...              4"
# 23  https://www.onthesnow.com/utah/snowbird/skireport              1"
#
#    last_snowfall base_depth          main_surface open_trails total_trails  \
# 0      Yesterday     80-80"        Packed Powder          115          119
# 1         Feb 12     53-53"        Packed Powder          120          147
# 2         Feb 06     36-61"        Packed Powder          336          336
# 3      Yesterday     42-60"      Machine Groomed            8           15
# 4      Yesterday     25-50"               Powder          295          317
# 5      Yesterday     37-37"      Machine Groomed           42           55
# 6         Feb 14     38-38"      Machine Groomed           53           60
# 7      Yesterday     67-67"      Machine Groomed           65           66
# 8         Feb 12     44-62"      Machine Groomed          150          150
# 9         Feb 15     55-70"  Variable Conditions           60           86
# 10        Feb 14   102-102"      Machine Groomed           30           61
# 11        Feb 02     45-45"        Packed Powder          103          103
# 12        Feb 12     30-30"      Machine Groomed           60           61
# 13     Yesterday     22-66"  Variable Conditions          123          131
# 14   2021 Dec 31     12-52"      Machine Groomed           41           43
# 15     Yesterday     57-85"        Packed Powder          159          160
# 16        Feb 08     32-41"      Machine Groomed           51           61
# 17   2021 Dec 30    68-130"  Variable Conditions          150          150
# 18     Yesterday     64-64"      Machine Groomed          105          119
# 19     Yesterday     46-46"      Machine Groomed           53           60
# 20        Feb 15        46"      Machine Groomed          151          245
# 21     Yesterday     92-92"      Machine Groomed           59           59
# 22     Yesterday     60-60"      Machine Groomed           22           27
# 23     Yesterday     75-75"        Packed Powder          123          140
#
#    open_lifts total_lifts
# 0           5           6
# 1           9           9
# 2          37          40
# 3           7          12
# 4          32          36
# 5          10          11
# 6           7          12
# 7           7           7
# 8          24          24
# 9           9          11
# 10          6           6
# 11         21          21
# 12         10          10
# 13         13          13
# 14          7           7
# 15         10          10
# 16          7          10
# 17         24          25
# 18         11          15
# 19          6           6
# 20         26          34
# 21          5           6
# 22          9          16
# 23         14          14

# %%
import geocoder
g = geocoder.bing('Snowbird', key='Aguwsj7-nplszsSo4Peqv4hCQDjcxuVRGeMiFUbfhu8xqfYt0rDn1at58zEGVtRQ')

# %%
g.json
# Out:
# {'address': 'Snowbird, United States',
#  'bbox': {'northeast': [40.61007847625427, -111.60554969422343],
#   'southwest': [40.552137710269164, -111.7072249639797]},
#  'city': 'Snowbird',
#  'confidence': 4,
#  'country': 'United States',
#  'lat': 40.58110809326172,
#  'lng': -111.65638732910156,
#  'ok': True,
#  'quality': 'PopulatedPlace',
#  'raw': {'__type': 'Location:http://schemas.microsoft.com/search/local/ws/rest/v1',
#   'bbox': [40.552137710269164,
#    -111.7072249639797,
#    40.61007847625427,
#    -111.60554969422343],
#   'name': 'Snowbird, United States',
#   'point': {'type': 'Point',
#    'coordinates': [40.58110809326172, -111.65638732910156]},
#   'address': {'countryRegion': 'United States',
#    'formattedAddress': 'Snowbird, United States',
#    'locality': 'Snowbird'},
#   'confidence': 'High',
#   'entityType': 'PopulatedPlace',
#   'geocodePoints': [{'type': 'Point',
#     'coordinates': [40.58110809326172, -111.65638732910156],
#     'calculationMethod': 'Rooftop',
#     'usageTypes': ['Display']}],
#   'matchCodes': ['Good']},
#  'status': 'OK'}

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome(executable_path='../chromedriver')

browser.get("https://www.onthesnow.com/ikon-pass/skireport")
time.sleep(1)

elem = browser.find_element_by_tag_name("body")

no_of_pagedowns = 50

while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    no_of_pagedowns-=1

post_elems = browser.find_elements_by_class_name("post-tbody-title")
# Out:
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_33838/3533580240.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path='../chromedriver')
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_33838/3533580240.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = browser.find_element_by_tag_name("body")
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_33838/3533580240.py:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   post_elems = browser.find_elements_by_class_name("post-tbody-title")

# %%
res = browser.find_element_by_tag_name('tbody')
# Out:
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_33838/1377574943.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   res = browser.find_element_by_tag_name('tbody')

# %%
html = res.get_attribute('outerHTML')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome(executable_path='../chromedriver')

browser.get("https://www.onthesnow.com/ikon-pass/skireport")
time.sleep(1)

elem = browser.find_element_by_tag_name("body")

no_of_pagedowns = 50

while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    no_of_pagedowns-=1

res = browser.find_element_by_tag_name('tbody')
html = res.get_attribute('outerHTML')

soup = BeautifulSoup(html, 'lxml')
tbodies = soup.find_all('tbody')
tbody = tbodies[0]
spots = []

spots = []
for row in tbody.findChildren(recursive=False)[:-1]:
    res = {}
    row_items = row.findChildren(recursive=False)
    if len(row_items) < 5:
        continue
    for i in range(len(row_items)):
        if i == 0:
            res['name'] = row_items[0].find('span').getText()
            res['last_update'] = row_items[0].find('time').getText()
            res['report_link'] = 'https://www.onthesnow.com' + row_items[0].find('a', href=True)['href']
        if i==1:
            res['snowfall_amount'] = row_items[1].find('span', {'class': 'h4 styles_h4__318ae'}).getText()
            res['last_snowfall'] = row_items[1].find('time').getText()
        if i==2:
            res['base_depth'] = row_items[2].find('span', {'class', 'h4 styles_h4__318ae'}).getText()
            res['main_surface'] = row_items[2].find('div').getText()
        if i==3:
            open_trails = row_items[3].find('span', {'class', 'h4 styles_h4__318ae'}).getText()
            res['open_trails'], res['total_trails'] = open_trails.split('/')
        if i==4:
            open_lifts = row_items[4].find('span', {'class', 'h4 styles_h4__318ae'} ).getText()
            res['open_lifts'], res['total_lifts'] = open_lifts.split('/')
    spots.append(res)
spots
df = pd.DataFrame(spots)
df.to_csv('snowfall.csv')
# Out:
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_34778/2937270341.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path='../chromedriver')
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_34778/2937270341.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = browser.find_element_by_tag_name("body")
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_34778/2937270341.py:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   post_elems = browser.find_elements_by_class_name("post-tbody-title")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1x/0p1yfnq13zlf42d52jz65rtm0000gp/T/ipykernel_34778/2937270341.py in <module>
#      25
#      26
# ---> 27 soup = BeautifulSoup(html, 'lxml')
#      28 tbodies = soup.find_all('tbody')
#      29 tbody = tbodies[0]
#
# NameError: name 'html' is not defined

# %%
tbody
# Out:
# <html><body><tbody><tr class="styles_row__wYlY6 styles_other__eO-mR"><th class="styles_title__2prXm"><a class="styles_title__2prXm" href="/utah/alta-ski-area/skireport"><span class="h4 styles_h4__318ae">Alta Ski Area</span><time title="Snow Report Last Updated:">5 hours ago</time></a></th><td><span class="h5 styles_h5__35Q9T">Snowfall</span><span class="h4 styles_h4__318ae">2"</span><time title="Last Snowfall Date">Today</time></td><td><span class="h5 styles_h5__35Q9T">Base Depth</span><span class="h4 styles_h4__318ae">84-84"</span><div class="styles_small__v-A50">Packed Powder<!-- --> </div></td><td><span class="h5 styles_h5__35Q9T">Open Trails</span><span class="h4 styles_h4__318ae">98/119</span><div></div></td><td><span class="h5 styles_h5__35Q9T">Open Lifts</span><span class="h4 styles_h4__318ae">5/6</span><div></div></td></tr><tr class="styles_row__wYlY6"><th class="styles_title__2prXm"><a class="styles_title__2prXm" href="/colorado/arapahoe-basin-ski-area/skireport"><span class="h4 styles_h4__318ae">Arapahoe Basin Ski Area</span><time title="Snow Report Last Updated:">7 hours ago</time></a></th><td><span class="h5 styles_h5__35Q9T">Snowfall</span><span class="h4 styles_h4__318ae">2"</span><time title="Last Snowfall Date">Feb 17</time></td><td><span class="h5 styles_h5__35Q9T">Base Depth</span><span class="h4 styles_h4__318ae">52-52"</span><div class="styles_small__v-A50">Packed Powder<!-- --> </div></td><td><span class="h5 styles_h5__35Q9T">Open Trails</span><span class="h4 styles_h4__318ae">136/147</span><div></div></td><td><span class="h5 styles_h5__35Q9T">Open Lifts</span><span class="h4 styles_h4__318ae">9/9</span><div></div></td></tr><tr class="styles_row__wYlY6 styles_other__eO-mR"><th class="styles_title__2prXm"><a class="styles_title__2prXm" href="/colorado/aspen-snowmass/skireport"><span class="h4 styles_h4__318ae">Aspen Snowmass</span><time title="Snow Report Last Updated:">11 hours ago</time></a></th><td><span class="h5 styles_h5__35Q9T">Snowfall</span><span class="h4 styles_h4__318ae">11"</span><time title="Last Snowfall Date">Feb 17</time></td><td><span class="h5 styles_h5__35Q9T">Base Depth</span><span class="h4 styles_h4__318ae">41-65"</span><div class="styles_small__v-A50">Packed Powder<!-- --> </div></td><td><span class="h5 styles_h5__35Q9T">Open Trails</span><span class="h4 styles_h4__318ae">333/336</span><div></div></td><td><span class="h5 styles_h5__35Q9T">Open Lifts</span><span class="h4 styles_h4__318ae">39/40</span><div></div></td></tr><tr class="styles_row__wYlY6"><th class="styles_title__2prXm"><a class="styles_title__2prXm" href="/california/bear-mountain/skireport"><span class="h4 styles_h4__318ae">Bear Mountain</span><time title="Snow Report Last Updated:">7 hours ago</time></a></th><td><span class="h5 styles_h5__35Q9T">Snowfall</span><span class="h4 styles_h4__318ae">4"</span><time title="Last Snowfall Date">Feb 16</time></td><td><span class="h5 styles_h5__35Q9T">Base Depth</span><span class="h4 styles_h4__318ae">42-60"</span><div class="styles_small__v-A50">Machine Groomed<!-- --> </div></td><td><span class="h5 styles_h5__35Q9T">Open Trails</span><span class="h4 styles_h4__318ae">15/15</span><div></div></td><td><span class="h5 styles_h5__35Q9T">Open Lifts</span><span class="h4 styles_h4__318ae">8/12</span><div></div></td></tr><tr class="styles_row__wYlY6 styles_other__eO-mR"><th class="styles_title__2prXm"><a class="styles_title__2prXm" href="/montana/big-sky-resort/skireport"><span class="h4 styles_h4__318ae">Big Sky</span><time title="Snow Report Last Updated:">10 hours ago</time></a></th><td><span class="h5 styles_h5__35Q9T">Snowfall</span><span class="h4 styles_h4__318ae">4"</span><time title="Last Snowfall Date">Today</time></td><td><span class="h5 styles_h5__35Q9T">Base Depth</span><span class="h4 styles_h4__318ae">29-57"</span><div class="styles_small__v-A50">Packed Powder<!-- --> </div></td><td><span class="h5 styles_h5__35Q9T">Open Trails</span><span class="h4 styles_h4__318ae">295/ ...

# %%
help(browser.find_elements_by_tag_name)
# Out:
# Help on method find_elements_by_tag_name in module selenium.webdriver.remote.webdriver:
#
# find_elements_by_tag_name(name) -> selenium.webdriver.remote.webelement.WebElement method of selenium.webdriver.chrome.webdriver.WebDriver instance
#     Finds elements by tag name.
#
#     :Args:
#      - name - name of html tag (eg: h1, a, span)
#
#     :Returns:
#      - list of WebElement - a list with elements if any was found.  An
#        empty list if not
#
#     :Usage:
#         ::
#
#             elements = driver.find_elements_by_tag_name('h1')
